# %% [markdown]
# <style>
# body {background-color: powderblue;}
# h1   {color: yellow; background-color:#339966}
# p    {color: white; background-color:grey}
# </style>
# <h1> Lab 1: Jupyter Notebook </h1>
# <p> In this Lab, we will make the simple python program with for-loop structure </p>
# <img alt="AVC logo" src="https://www.avc.edu/sites/default/files/palmdale/avclogocolor.png"> AVC Logo </img>

# %%
for i in range(5):
    print (i, "CS110 Introduction to Programming ")
# Out:
# 0 CS110 Introduction to Programming
# 1 CS110 Introduction to Programming
# 2 CS110 Introduction to Programming
# 3 CS110 Introduction to Programming
# 4 CS110 Introduction to Programming
